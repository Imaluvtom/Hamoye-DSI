# %%
A = [1,2,4]
B = [5,6,7]
A_B = A+B
print(A_B)
# Out:
# [1, 2, 4, 5, 6, 7]

# %%
import pandas as pd
import numpy as np

# %%
data_link = 'https://raw.githubusercontent.com/WalePhenomenon/climate_change/master/fuel_ferc1.csv'
dataset = pd.read_csv(data_link)

# %%
dataset.head(10)
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
# 5  f1_fuel_1994_12_2_0_13                 2         1994
# 6   f1_fuel_1994_12_2_1_1                 2         1994
# 7  f1_fuel_1994_12_2_1_10                 2         1994
# 8  f1_fuel_1994_12_2_2_10                 2         1994
# 9   f1_fuel_1994_12_4_0_1                 4         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# ...

# %%
groupA= dataset.groupby('fuel_type_code_pudl').mean()

groupA
# Out:
#                      utility_id_ferc1  report_year  fuel_qty_burned  \
# fuel_type_code_pudl
# coal                       115.637534  2004.623143     1.903473e+06
# gas                        124.122062  2005.978060     4.843183e+06
# nuclear                    107.397311  2002.970660     5.454838e+06
# oil                        113.236235  2007.195933     6.311677e+04
# other                      110.467066  2001.700599     2.948137e+06
# waste                      154.253968  2005.650794     1.171914e+05
#
#                      fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# fuel_type_code_pudl
# coal                           20.762780                  67.421830
# gas                             1.021913                  13.659397
# nuclear                        17.582120                4955.157002
# oil                             5.814377                 168.877086
# other                           0.572752                  18.253856
# ...

# %%
print(dataset.std())
# Out:
# utility_id_ferc1                7.417835e+01
# report_year                     7.025483e+00
# fuel_qty_burned                 9.118004e+06
# fuel_mmbtu_per_unit             1.060022e+01
# fuel_cost_per_unit_burned       2.854490e+03
# fuel_cost_per_unit_delivered    6.877593e+04
# fuel_cost_per_mmbtu             2.091541e+03
# dtype: float64

# %%
#df.groupby('group').quantile([0.25,0.50,0.75])
dataset.quantile([0.75])
# Out:
#       utility_id_ferc1  report_year  fuel_qty_burned  fuel_mmbtu_per_unit  \
# 0.75             176.0       2012.0        1424034.0               17.006
#
#       fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# 0.75                     47.113                        42.137
#
#       fuel_cost_per_mmbtu
# 0.75                7.745

# %%
from scipy.stats import skew
from scipy.stats import kurtosis

# %%
skewness= skew(dataset["fuel_qty_burned"].dropna())
kurtosis= kurtosis(dataset["fuel_qty_burned"].dropna())
print('skewness=', skewness)
print('kurtosis=', kurtosis)
# Out:
# skewness= 15.850690077422112
# kurtosis= 651.2589365474387

# %%
print(dataset.isnull().sum())
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
groupC = dataset.groupby('report_year')
groupC

# %%
groupB= dataset.groupby('fuel_cost_per_unit_delivered').mean()
groupB
# Out:
#                               utility_id_ferc1  report_year  fuel_qty_burned  \
# fuel_cost_per_unit_delivered
# -874.937                                 177.0       2008.0       811.000000
# -488.054                                 177.0       2007.0      2240.000000
# -313.410                                 210.0       2004.0       588.000000
# -174.670                                 194.0       2000.0        77.333333
# -170.187                                   6.0       2015.0      2292.000000
# ...                                        ...          ...              ...
#  1942979.000                               9.0       1997.0     52526.000000
#  2114508.000                               9.0       1996.0     58795.000000
#  2255688.000                               9.0       1997.0     36919.000000
#  7793482.000                               9.0       1996.0    211407.000000
#  7964521.000                               9.0       1997.0    210474.000000
#
# ...

# %%
groupD = dataset.groupby(['report_year','fuel_cost_per_unit_delivered'], as_index=False)['fuel_cost_per_unit_delivered'].mean()
groupD
# Out:
#        report_year  fuel_cost_per_unit_delivered
# 0             1994                       -58.800
# 1             1994                       -35.380
# 2             1994                         0.000
# 3             1994                         0.027
# 4             1994                         0.979
# ...            ...                           ...
# 22802         2018                      2956.400
# 22803         2018                      6952.161
# 22804         2018                     88419.000
# 22805         2018                     92484.000
# 22806         2018                    245652.000
#
# [22807 rows x 2 columns]

# %%
groupE = dataset.groupby(['report_year','fuel_cost_per_unit_delivered'])
groupE.head()
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29517  f1_fuel_2018_12_12_0_10                12         2018
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
dataset.corr()
# Out:
#                               utility_id_ferc1  report_year  fuel_qty_burned  \
# utility_id_ferc1                      1.000000     0.093323        -0.057447
# report_year                           0.093323     1.000000         0.012952
# fuel_qty_burned                      -0.057447     0.012952         1.000000
# fuel_mmbtu_per_unit                  -0.066946    -0.110853        -0.080946
# fuel_cost_per_unit_burned            -0.037863     0.013599        -0.018535
# fuel_cost_per_unit_delivered         -0.016414    -0.014043        -0.003551
# fuel_cost_per_mmbtu                   0.006122     0.010261        -0.001896
#
#                               fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# utility_id_ferc1                        -0.066946                  -0.037863
# report_year                             -0.110853                   0.013599
# fuel_qty_burned                         -0.080946                  -0.018535
# ...

# %%
groupF = dataset.groupby(['fuel_type_code_pudl','report_year']).sum()
groupF.head(10)
# Out:
#                                  utility_id_ferc1  fuel_qty_burned  \
# fuel_type_code_pudl report_year
# coal                1994                    50430     7.172082e+08
#                     1995                    51231     1.257398e+09
#                     1996                    45720     6.988514e+08
#                     1997                    44254     8.169024e+08
#                     1998                    46403     8.982095e+08
#                     1999                    45126     8.805301e+08
#                     2000                    44271     8.620492e+08
#                     2001                    40232     8.564316e+08
#                     2002                    38592     8.144357e+08
#                     2003                    38876     8.018815e+08
#
#                                  fuel_mmbtu_per_unit  \
# fuel_type_code_pudl report_year
# coal                1994                10293.429297
#                     1995                10262.019015
# ...

# %%
change = ((11902.597 - 14984.572)/14984.572)*100
change
# Out:
# -20.567654518260518
